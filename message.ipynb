# %% [markdown]
# SystemMessage  → Rules for the AI
#        ↓
# HumanMessage   → User speaks
#        ↓
# AIMessage      → AI replies
#        ↓
# HumanMessage   → User speaks again
#        ↓
# AIMessage      → AI replies
#
# | Message Type    | Represents             | Who sends it?   |
# | --------------- | ---------------------- | --------------- |
# | `SystemMessage` | Instructions/rules     | Developer       |
# | `HumanMessage`  | User's question        | User            |
# | `AIMessage`     | AI's previous response | Assistant (LLM) |
